# %%
print("Hello world")

# %%
#trying out doc2vec
from gensim.parsing.porter import PorterStemmer
from gensim.parsing.preprocessing import remove_stopwords
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.utils import simple_preprocess
import pandas as pd

class MyCorpus:
    def __init__(self, train_data):
        self.train_data = train_data
        
    def iter(self):
        p = PorterStemmer()
        for index, row in self.train_data.iterrows():
            name = row['ScriptLink']
            with open('../movie_scripts/' + name) as file:
                print("Im here")
                script = file.readlines()
                script = "".join(script)
                script = remove_stopwords(script)
                script = p.stem_sentence(script)
                words = simple_preprocess(script)
                yield TaggedDocument(words=words, tags=[index])

# %%
class Doc2VecTrainer:
    def __init__(self, train_corpus):
        self.train_corpus = train_corpus

    def run(self):
        print('app started')

        #cores = multiprocessing.cpu_count()
        #print('num of cores is %s' % cores)
        #gc.collect()
        load_existing = False
        if load_existing:
            print('loading an exiting model')
            model = Doc2Vec.load(PATH_TO_EXISTING_MODEL)
        else:
            print('reading training corpus from %s' % self.train_corpus)
            corpus_data = MyCorpus(self.train_corpus)
            
            model_dimensions = 100
            model = Doc2Vec(size=model_dimensions, window=10, min_count=3, sample=1e-4, negative=5, workers=cores, dm=1)
            print('building vocabulary...')
            model.build_vocab(corpus_data)

            model.train(corpus_data, total_examples=model.corpus_count, epochs=20)
            
            model.save(doc2vec_model)
            model.save_word2vec_format(word2vec_model)

        print('total docs learned %s' % (len(model.docvecs)))

# %%
#corpus = MyCorpus()
#for vector in corpus:  # load one vector into memory at a time
   # print(vector)

    
df = pd.read_csv('data_parsed.csv')
doc2vec_model = Doc2VecTrainer(df)
doc2vec_model.run()
# Out:
# app started
# reading training corpus from       Unnamed: 0                                        MovieTitle  \
# 0              0                                            avatar
# 1              1              star wars ep. vii: the force awakens
# 2              2                             the dark knight rises
# 3              3            harry potter and the half-blood prince
# 4              4                                      the avengers
# 5              5      pirates of the caribbean: dead manâs chest
# 6              6                            the amazing spider-man
# 7              7                                    men in black 3
# 8              8                                         king kong
# 9              9                                     black panther
# 10            10                                           titanic
# 11            11                     guardians of the galaxy vol 2
# 12            12                                            cars 2
# 13            13                                      tron: legacy
# 14            14                                              2012
# 15            15                              terminator salvation
# 16            16                                         the mummy
# 17            17                           star trek into darkness
# 18            18                                  the great gatsby
# 19            19                                   the dark knight
# 20            20                                  star trek beyond
# 21            21                                           aladdin
# 22            22  the chronicles of narnia: the lion, the witch a…
# 23            23                                            wall-e
# 24            24                              the legend of tarzan
# 25            25                                                up
# 26            26                                              coco
# 27            27                       g.i. joe: the rise of cobra
# 28            28                                    wild wild west
# 29            29                                          47 ronin
# ...          ...                                               ...
# 1262        1262                                    to save a life
# 1263        1263                                          monsters
# 1264        1264                                   insomnia manica
# 1265        1265                                 the toxic avenger
# 1266        1266                                             brick
# 1267        1267                                 napoleon dynamite
# 1268        1268                                     the evil dead
# 1269        1269                                         halloween
# 1270        1270                             it happened one night
# 1271        1271                                       chasing amy
# 1272        1272                                              cube
# 1273        1273                                        sugar town
# 1274        1274                                        the frozen
# 1275        1275                                         butterfly
# 1276        1276                                    the big parade
# 1277        1277                                    little big top
# 1278        1278                                              burn
# 1279        1279                                          swingers
# 1280        1280                               theresa is a mother
# 1281        1281                                                h.
# 1282        1282                                     a ghost story
# 1283        1283                                 the night visitor
# 1284        1284                         dawn of the crescent moon
# 1285        1285                                                pi
# 1286        1286                                        big things
# 1287        1287                                    raymond did it
# 1288        1288                           the legend of god's gun
# 1289        1289                                            clerks
# 1290        1290                                     the terrorist
# 1291        1291                                       el mariachi
#
#                                              ScriptLink  ProductionBudget  \
# 0                                           avatar.html       425000000.0
# 1                     star-wars:-the-force-awakens.html       306000000.0
# 2                           dark-knight-rises,-the.html       275000000.0
# 3           harry-potter-and-the-half-blood-prince.html       250000000.0
# 4                                    avengers,-the.html       225000000.0
# 5       pirates-of-the-caribbean:-dead-man's-chest.html       225000000.0
# 6                                       spider-man.html       220000000.0
# 7                                   men-in-black-3.html       215000000.0
# 8                                        king-kong.html       207000000.0
# 9                                    black-panther.html       200000000.0
# 10                                         titanic.html       200000000.0
# 11                   guardians-of-the-galaxy-vol-2.html       200000000.0
# 12                                          cars-2.html       200000000.0
# 13                                    tron:-legacy.html       200000000.0
# 14                                            2012.html       200000000.0
# 15                            terminator-salvation.html       200000000.0
# 16                                            they.html       195000000.0
# 17                              star-trek:-nemesis.html       190000000.0
# 18                               great-gatsby,-the.html       190000000.0
# 19                                dark-knight,-the.html       185000000.0
# 20                                       star-trek.html       185000000.0
# 21                                         aladdin.html       182000000.0
# 22    chronicles-of-narnia:-the-lion,-the-witch-and-...       180000000.0
# 23                                          wall-e.html       180000000.0
# 24                                          legend.html       180000000.0
# 25                                              up.html       175000000.0
# 26                                            coco.html       175000000.0
# 27                     g.i.-joe:-the-rise-of-cobra.html       175000000.0
# 28                                  wild-wild-west.html       175000000.0
# 29                                           ronin.html       175000000.0
# ...                                                 ...               ...
# 1262                               this-boy's-life.html          500000.0
# 1263                                monster's-ball.html          500000.0
# 1264                                      insomnia.html          500000.0
# 1265                             american-gangster.html          475000.0
# 1266                                         brick.html          450000.0
# 1267                             napoleon-dynamite.html          400000.0
# 1268                                     evil-dead.html          375000.0
# 1269                                     halloween.html          325000.0
# 1270                         it-happened-one-night.html          325000.0
# 1271                                   chasing-amy.html          250000.0
# 1272                                          cube.html          250000.0
# 1273                                         sugar.html          250000.0
# 1274                                        frozen.html          250000.0
# 1275                         butterfly-effect,-the.html          250000.0
# 1276                                       charade.html          245000.0
# 1277                                  little-nicky.html          240000.0
# 1278                                         bound.html          225000.0
# 1279                                      swingers.html          200000.0
# 1280                                    hellraiser.html          200000.0
# 1281                                           her.html          200000.0
# 1282                                  ghostbusters.html          100000.0
# 1283                                    date-night.html          100000.0
# 1284                              dawn-of-the-dead.html           75000.0
# 1285                                            pi.html           68000.0
# 1286                                   wild-things.html           50000.0
# 1287                                         ronin.html           40000.0
# 1288                                   logan's-run.html           30000.0
# 1289                                        clerks.html           27000.0
# 1290                              eastern-promises.html           25000.0
# 1291                                   el-mariachi.html            7000.0
#
#       DomesticGross  WorldwideGross        Profit  IsProfitable
# 0       760507625.0    2.789705e+09  2.364705e+09          True
# 1       936662225.0    2.053311e+09  1.747311e+09          True
# 2       448139099.0    1.084439e+09  8.094391e+08          True
# 3       302089278.0    9.352138e+08  6.852138e+08          True
# 4       623279547.0    1.517936e+09  1.292936e+09          True
# 5       423315812.0    1.066216e+09  8.412158e+08          True
# 6       262030663.0    7.578903e+08  5.378903e+08          True
# 7       179020854.0    6.542135e+08  4.392135e+08          True
# 8       218080025.0    5.505174e+08  3.435174e+08          True
# 9       700059566.0    1.348258e+09  1.148258e+09          True
# 10      659363944.0    2.208208e+09  2.008208e+09          True
# 11      389813101.0    8.623162e+08  6.623162e+08          True
# 12      191450875.0    5.601554e+08  3.601554e+08          True
# 13      172062763.0    4.000628e+08  2.000628e+08          True
# 14      166112167.0    7.576777e+08  5.576777e+08          True
# 15      125322469.0    3.654918e+08  1.654918e+08          True
# 16       80101125.0    4.099539e+08  2.149539e+08          True
# 17      228778661.0    4.673816e+08  2.773816e+08          True
# 18      144840419.0    3.510404e+08  1.610404e+08          True
# 19      533720947.0    1.001996e+09  8.169962e+08          True
# 20      158848340.0    3.358022e+08  1.508022e+08          True
# 21      355557222.0    1.038057e+09  8.560572e+08          True
# 22      291710957.0    7.205396e+08  5.405396e+08          True
# 23      223808164.0    5.325080e+08  3.525080e+08          True
# 24      126643061.0    3.489020e+08  1.689020e+08          True
# 25      293004164.0    7.314634e+08  5.564634e+08          True
# 26      209726015.0    7.980020e+08  6.230020e+08          True
# 27      150201498.0    3.024690e+08  1.274690e+08          True
# 28      113805681.0    2.212293e+08  4.622934e+07          True
# 29       38362475.0    1.517168e+08 -2.328318e+07         False
# ...             ...             ...           ...           ...
# 1262      3777210.0    3.824868e+06  3.324868e+06          True
# 1263       237301.0    5.639730e+06  5.139730e+06          True
# 1264            0.0    0.000000e+00 -5.000000e+05         False
# 1265            0.0    0.000000e+00 -4.750000e+05         False
# 1266      2075743.0    4.243996e+06  3.793996e+06          True
# 1267     44540956.0    4.612271e+07  4.572271e+07          True
# 1268      2400000.0    2.940000e+07  2.902500e+07          True
# 1269     47000000.0    7.000000e+07  6.967500e+07          True
# 1270      2500000.0    2.500000e+06  2.175000e+06          True
# 1271     12006514.0    1.515510e+07  1.490510e+07          True
# 1272       489220.0    8.969065e+06  8.719065e+06          True
# 1273       178095.0    1.780950e+05 -7.190500e+04         False
# 1274            0.0    0.000000e+00 -2.500000e+05         False
# 1275            0.0    0.000000e+00 -2.500000e+05         False
# 1276     11000000.0    2.200000e+07  2.175500e+07          True
# 1277         7484.0    7.484000e+03 -2.325160e+05         False
# 1278      1109276.0    1.109276e+06  8.842760e+05          True
# 1279      4505922.0    6.618578e+06  6.418578e+06          True
# 1280            0.0    0.000000e+00 -2.000000e+05         False
# 1281            0.0    0.000000e+00 -2.000000e+05         False
# 1282      1594798.0    2.769782e+06  2.669782e+06          True
# 1283            0.0    0.000000e+00 -1.000000e+05         False
# 1284         8799.0    8.799000e+03 -6.620100e+04         False
# 1285      3221152.0    4.678513e+06  4.610513e+06          True
# 1286            0.0    0.000000e+00 -5.000000e+04         False
# 1287         3632.0    3.632000e+03 -3.636800e+04         False
# 1288       243768.0    2.437680e+05  2.137680e+05          True
# 1289      3073428.0    3.894240e+06  3.867240e+06          True
# 1290       195043.0    1.950430e+05  1.700430e+05          True
# 1291      2040920.0    2.041928e+06  2.034928e+06          True
#
# [1292 rows x 8 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cd556e04623b> in <module>
#       6 df = pd.read_csv('data_parsed.csv')
#       7 doc2vec_model = Doc2VecTrainer(df)
# ----> 8 doc2vec_model.run()
#
# <ipython-input-18-39987bc4e03c> in run(self)
#      18
#      19             model_dimensions = 100
# ---> 20             model = Doc2Vec(size=model_dimensions, window=10, min_count=3, sample=1e-4, negative=5, workers=cores, dm=1)
#      21             print('building vocabulary...')
#      22             model.build_vocab(corpus_data)
#
# NameError: name 'cores' is not defined
